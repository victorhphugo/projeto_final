# %% [markdown]
# # Importando os dados

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('dataset/imigrantes_canada.csv')
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %% [markdown]
# # Processamento e tratamento de dados para a leitura Machine learning

# %%
df_index_pais = df.set_index('País')  # Define 'País' como índice
brasil = df_index_pais.loc['Brasil']  # Seleciona a linha  Brasil como uma Série

# Reseta o índice e transforma a série em um DataFrame (opcional, se precisar de visualização)
brasil = brasil.reset_index()

# Agora, remova as duas primeiras linhas (supondo que queira remover as primeiras linhas com base na posição)
brasil = brasil.iloc[2:]

# Se precisar voltar a ter um índice sequencial
brasil = brasil.reset_index(drop=True)

brasil = brasil[brasil.index != 34] # retirando a linha de numero 34 que se refere ao total de imigrantes 
brasil.columns =["Ano","Imigrantes"] 
x = brasil['Ano']
y = brasil['Imigrantes']

# %%
brasil.plot(kind='scatter', x='Ano', y='Imigrantes');

# %%
from sklearn import linear_model
modelo = linear_model.LinearRegression()
x = brasil[["Ano"]]
y = brasil[["Imigrantes"]]

modelo.fit(x,y)
# Out:
# LinearRegression()

# %%
print (modelo.predict([[2018]])[0][0])
# Out:
# 2076.37280366692
# c:\Users\ead\Documents\documentos_victor\projeto_ml\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import streamlit as st
st.title("Qual o valor aproximado de imigrações do Brasil para o Canada")
# Out:
# 2024-09-03 16:19:31.740 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 16:19:32.276
# ...
#   command:
#
#     streamlit run c:\Users\ead\Documents\documentos_victor\projeto_ml\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-09-03 16:19:32.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
import streamlit as st

# CSS para adicionar uma imagem de fundo
background_css = """
<style>
body {
    background-image: url("imagem_fundo.webp");
    background-size: cover;
    background-repeat: no-repeat;
    background-attachment: fixed;
}
</style>
"""

# Inserir o CSS no Streamlit
st.markdown(background_css, unsafe_allow_html=True)

# Conteúdo do seu aplicativo
st.title("Meu Aplicativo Streamlit com Imagem de Fundo")
st.write("Este é um exemplo de como adicionar uma imagem de fundo no Streamlit.")
# Out:
# 2024-09-03 16:19:32.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 16:19:32.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 16:19:32.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 16:19:32.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 16:19:32.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 16:19:32.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-03 16:19:32.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
